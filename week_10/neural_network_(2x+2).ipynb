# %% [markdown]
# <a href="https://colab.research.google.com/github/cisnux-seed/machine-learning-course/blob/main/week_10/neural_network_(2x%2B2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### NIM: 11020032
# ### Nama: Fajra Risqulla
# ### Kelas: TK-44-06

# %%
import numpy as np
import tensorflow as tf

# %%
np.random.seed(0)
X_train = np.random.rand(100, 1) * 2
y_train = 2 * X_train + 2 + np.random.randn(100, 1)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=100, verbose=2)

X_test = np.array([[1.0], [2.0], [3.0]])
y_pred = model.predict(X_test)

for i in range(len(X_test)):
    print(f'Input: {X_test[i][0]}, Predicted Output: {y_pred[i][0]}')
# Out:
# Epoch 1/100
# 4/4 - 5s - loss: 9.3745 - 5s/epoch - 1s/step
# Epoch 2/100
# 4/4 - 0s - loss: 9.3292 - 12ms/epoch - 3ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 9.2830 - 12ms/epoch - 3ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 9.2393 - 12ms/epoch - 3ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 9.1947 - 12ms/epoch - 3ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 9.1508 - 12ms/epoch - 3ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 9.1071 - 11ms/epoch - 3ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 9.0624 - 13ms/epoch - 3ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 9.0206 - 12ms/epoch - 3ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 8.9781 - 19ms/epoch - 5ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 8.9356 - 20ms/epoch - 5ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 8.8921 - 14ms/epoch - 4ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 8.8497 - 16ms/epoch - 4ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 8.8068 - 17ms/epoch - 4ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 8.7628 - 17ms/epoch - 4ms/step
# Epoch 16/100
# ...
